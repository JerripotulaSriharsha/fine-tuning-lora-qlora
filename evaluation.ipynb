# %%
import json
import pandas as pd
import sys
import os

# Add src directory to path to import our modules
sys.path.append('src')

# Import our QLoRA model loading function
from load_qlora_model import load_qlora_model, ask_financial_risk_qlora

# Load the evaluation examples
with open('evaluation_examples.json', 'r') as f:
    evaluation_data = json.load(f)

print(f"✅ Loaded {len(evaluation_data)} evaluation examples")
print(f"📊 Distribution:")
for item in evaluation_data:
    print(f"   • {item['answer']}: {item['question'][:50]}...")
# Out:
# ✅ Loaded 10 evaluation examples
# 📊 Distribution:
#    • Good: Age: 19.0, Occupation: Musician, Annual Income: 18...
#    • Good: Age: 20.0, Occupation: Doctor, Annual Income: 3819...
#    • Good: Age: 37.0, Occupation: Doctor, Annual Income: 1461...
#    • Good: Age: 23.0, Occupation: Musician, Annual Income: 19...
#    • Standard: Age: 17.0, Occupation: Manager, Annual Income: 442...
#    • Standard: Age: 31.0, Occupation: Teacher, Annual Income: 788...
#    • Standard: Age: 39.0, Occupation: Scientist, Annual Income: 3...
#    • Bad: Age: 22.0, Occupation: Media_Manager, Annual Incom...
#    • Bad: Age: 38.0, Occupation: Mechanic, Annual Income: 44...
#    • Bad: Age: 37.0, Occupation: Mechanic, Annual Income: 18...

# %%
# Load the QLoRA model
print("🔄 Loading QLoRA model...")
try:
    llm = load_qlora_model()
    print("✅ QLoRA model loaded successfully!")
except Exception as e:
    print(f"❌ Error loading model: {e}")
    llm = None
# Out:
# 🔄 Loading QLoRA model...
# llama_context: n_ctx_per_seq (2048) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ✅ QLoRA model loaded successfully!

# %%
# Run predictions on all evaluation samples
if llm is not None:
    print("🚀 Running predictions on all 10 evaluation samples...")
    print("=" * 100)
    
    results = []
    
    for i, example in enumerate(evaluation_data, 1):
        print(f"\n📝 SAMPLE {i}/{len(evaluation_data)}")
        print(f"Expected: {example['answer']}")
        print(f"Input: {example['question']}")
        print("-" * 80)
        
        try:
            # Get prediction from QLoRA model
            prediction = ask_financial_risk_qlora(example['question'], llm)
            
            # Store result
            result = {
                'sample': i,
                'expected': example['answer'],
                'input': example['question'],
                'prediction': prediction
            }
            results.append(result)
            
            print(f"🤖 Model Prediction:")
            print(prediction)
            
        except Exception as e:
            print(f"❌ Error getting prediction: {e}")
            result = {
                'sample': i,
                'expected': example['answer'],
                'input': example['question'],
                'prediction': f"ERROR: {e}"
            }
            results.append(result)
        
        print("=" * 100)
    
    print(f"\n✅ Completed predictions for all {len(evaluation_data)} samples!")
    
else:
    print("❌ Cannot run predictions - model not loaded")
# Out:
# 🚀 Running predictions on all 10 evaluation samples...
# ====================================================================================================
#
# 📝 SAMPLE 1/10
# Expected: Good
# Input: Age: 19.0, Occupation: Musician, Annual Income: 18246.25_, Outstanding Debt: 845.61, Credit Utilization Ratio: 40.44063497957373, Payment Behaviour: Low_spent_Small_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# The individual is a 19-year-old musician with an annual income of $18,246. This suggests they are likely in their early stages of financial life and may be more susceptible to impulsive spending or debt accumulation due to lack of experience managing finances independently. Their credit utilization ratio at 40% is considered standard for someone who has a mix of revolving (credit cards) and possibly installment debts, which indicates that while not perfect, they are using their available credit within reasonable limits compared to the total amount owed.
#
# Their annual income ($18,246) does not cover their outstanding debt ($845.61), indicating an immediate need for financial management strategies such as prioritizing payments and possibly seeking advice from a personal finance counselor or advisor who can help them understand better how they are managing money.
# </reasoning>
# Bad
#
# The individual's age, being 19 years old, suggests that their experience in handling finances is limited. Given the high credit utilization ratio of 40%, it indicates potential over-reliance on debt to meet expenses or purchase items beyond immediate needs.
#
# Additionally, despite having an annual income of $18,246 and a low payment behavior characterized by small value payments (Low_spent_Small_value_payments), they still have outstanding debts amounting to around 5% of their total credit limit. This combination suggests that the individual might be struggling with debt management or may not fully understand how much financial responsibility comes with having access to revolving lines of credit.
#
# Therefore, given these factors, it is reasonable to classify this profile as "Bad" in terms of overall risk for managing finances effectively and avoiding potential future financial difficulties.
# </reasoning>
# Bad
#
# The individual's young age (19) suggests a lack of experience in handling personal finance. The high credit utilization ratio at 40% indicates that they are using more than half their available credit, which is concerning given the relatively low annual income ($18,246). This could suggest overspending or difficulty managing debt.
#
# Additionally, despite having an average payment behavior (Low_spent_Small_value_payments), there's still a significant amount of outstanding debt. The combination of these factors points to potential financial instability and risk in handling future expenses without additional guidance on better budgeting and credit management.
# </reasoning>
# Bad
#
# The individual is 19 years old, which typically means they are at the beginning stages of🤖 Model Prediction:
# <reasoning>
# The individual is a 19-year-old musician with an annual income of $18,246. This suggests they are likely in their early stages of financial life and may be more susceptible to impulsive spending or debt accumulation due to lack of experience managing finances independently. Their credit utilization ratio at 40% is considered standard for someone who has a mix of revolving (credit cards) and possibly installment debts, which indicates that while not perfect, they are using their available credit within reasonable limits compared to the total amount owed.
#
# Their annual income ($18,246) does not cover their outstanding debt ($845.61), indicating an immediate need for financial management strategies such as prioritizing payments and possibly seeking advice from a personal finance counselor or advisor who can help them understand better how they are managing money.
# </reasoning>
# Bad
#
# The individual's age, being 19 years old, suggests that their experience in handling finances is limited. Given the high credit utilization ratio of 40%, it indicates potential over-reliance on debt to meet expenses or purchase items beyond immediate needs.
#
# Additionally, despite having an annual income of $18,246 and a low payment behavior characterized by small value payments (Low_spent_Small_value_payments), they still have outstanding debts amounting to around 5% of their total credit limit. This combination suggests that the individual might be struggling with debt management or may not fully understand how much financial responsibility comes with having access to revolving lines of credit.
#
# Therefore, given these factors, it is reasonable to classify this profile as "Bad" in terms of overall risk for managing finances effectively and avoiding potential future financial difficulties.
# </reasoning>
# Bad
#
# The individual's young age (19) suggests a lack of experience in handling personal finance. The high credit utilization ratio at 40% indicates that they are using more than half their available credit, which is concerning given the relatively low annual income ($18,246). This could suggest overspending or difficulty managing debt.
#
# Additionally, despite having an average payment behavior (Low_spent_Small_value_payments), there's still a significant amount of outstanding debt. The combination of these factors points to potential financial instability and risk in handling future expenses without additional guidance on better budgeting and credit management.
# </reasoning>
# Bad
#
# The individual is 19 years old, which typically means they are at the beginning stages of
# ====================================================================================================
#
# 📝 SAMPLE 2/10
# Expected: Good
# Input: Age: 20.0, Occupation: Doctor, Annual Income: 38197.25, Outstanding Debt: 898.75, Credit Utilization Ratio: 30.700684566089016, Payment Behaviour: High_spent_Medium_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# Based on the information provided, this individual appears to have a good credit profile. They are in their early twenties and already earning an annual income of $38197.25 as a doctor, which is quite substantial for someone at that age. The outstanding debt amount ($898.75) seems manageable given the high income level. Their low Credit Utilization Ratio (30.7%) indicates they are not overextending themselves with credit compared to their available limits. Additionally, having "High_spent_Medium_value_payments" suggests a responsible spending pattern without excessive debt accumulation or frequent small transactions that might indicate impulsive buying habits.
#
# </reasoning>
# <answer>Good</answer>🤖 Model Prediction:
# <reasoning>
# Based on the information provided, this individual appears to have a good credit profile. They are in their early twenties and already earning an annual income of $38197.25 as a doctor, which is quite substantial for someone at that age. The outstanding debt amount ($898.75) seems manageable given the high income level. Their low Credit Utilization Ratio (30.7%) indicates they are not overextending themselves with credit compared to their available limits. Additionally, having "High_spent_Medium_value_payments" suggests a responsible spending pattern without excessive debt accumulation or frequent small transactions that might indicate impulsive buying habits.
#
# </reasoning>
# <answer>Good</answer>
# ====================================================================================================
#
# 📝 SAMPLE 3/10
# Expected: Good
# Input: Age: 37.0, Occupation: Doctor, Annual Income: 14619.875_, Outstanding Debt: 107.8, Credit Utilization Ratio: 33.09344778317082, Payment Behaviour: Low_spent_Small_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# The individual's age of 37 is considered young for retirement, which suggests they are likely in a high-risk category due to potential future health issues or career changes. As a doctor with an annual income of $14619.875_, the person has significant financial stability and resources compared to their outstanding debt (which seems low at 107.8). However, credit utilization ratio is relatively high at 33%, which could indicate potential future issues if spending habits change or unexpected expenses occur.
#
# The payment behavior described as "Low_spent_Small_value_payments" suggests a pattern of small and infrequent payments rather than consistent large ones, indicating possible financial discipline but also caution in managing debt. This can be seen both positively (consistent with low risk) and negatively (could imply difficulty paying off larger debts).
#
# Overall, the individual appears to have good control over their finances despite some areas needing improvement.
# </reasoning>
# answer
# Good🤖 Model Prediction:
# <reasoning>
# The individual's age of 37 is considered young for retirement, which suggests they are likely in a high-risk category due to potential future health issues or career changes. As a doctor with an annual income of $14619.875_, the person has significant financial stability and resources compared to their outstanding debt (which seems low at 107.8). However, credit utilization ratio is relatively high at 33%, which could indicate potential future issues if spending habits change or unexpected expenses occur.
#
# The payment behavior described as "Low_spent_Small_value_payments" suggests a pattern of small and infrequent payments rather than consistent large ones, indicating possible financial discipline but also caution in managing debt. This can be seen both positively (consistent with low risk) and negatively (could imply difficulty paying off larger debts).
#
# Overall, the individual appears to have good control over their finances despite some areas needing improvement.
# </reasoning>
# answer
# Good
# ====================================================================================================
#
# 📝 SAMPLE 4/10
# Expected: Good
# Input: Age: 23.0, Occupation: Musician, Annual Income: 19028.33, Outstanding Debt: 457.92, Credit Utilization Ratio: 36.66173025979048, Payment Behaviour: Low_spent_Small_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# The individual is a 23-year-old musician with an annual income of $19,028. This suggests they are likely in the early stages of their career and may be experiencing financial instability or irregularity due to variable earnings from music performances. The outstanding debt amount ($457.92) seems manageable given their low-income level but is not negligible either. Their credit utilization ratio (36%) falls within a reasonable range, indicating they are using less than half of their available credit which is generally seen as prudent behavior.
#
# However, the payment behaviour described ("Low_spent_Small_value_payments") suggests that this individual tends to make small payments rather than larger ones on time or in full. This could indicate financial prudence but might also mean missed opportunities for building a stronger positive payment history and potentially lower interest rates if they were able to pay more frequently.
#
# Given these factors, the overall risk level is considered "Standard." The income level suggests some vulnerability due to its low value compared to typical middle-class incomes; however, given their young age and potential room for career growth in music, there's also a possibility of improving financial health over time. Their credit utilization ratio indicates responsible borrowing habits but does not provide strong evidence that they are making significant progress towards building up positive payment history.
# </reasoning>
# answer
# Standard🤖 Model Prediction:
# <reasoning>
# The individual is a 23-year-old musician with an annual income of $19,028. This suggests they are likely in the early stages of their career and may be experiencing financial instability or irregularity due to variable earnings from music performances. The outstanding debt amount ($457.92) seems manageable given their low-income level but is not negligible either. Their credit utilization ratio (36%) falls within a reasonable range, indicating they are using less than half of their available credit which is generally seen as prudent behavior.
#
# However, the payment behaviour described ("Low_spent_Small_value_payments") suggests that this individual tends to make small payments rather than larger ones on time or in full. This could indicate financial prudence but might also mean missed opportunities for building a stronger positive payment history and potentially lower interest rates if they were able to pay more frequently.
#
# Given these factors, the overall risk level is considered "Standard." The income level suggests some vulnerability due to its low value compared to typical middle-class incomes; however, given their young age and potential room for career growth in music, there's also a possibility of improving financial health over time. Their credit utilization ratio indicates responsible borrowing habits but does not provide strong evidence that they are making significant progress towards building up positive payment history.
# </reasoning>
# answer
# Standard
# ====================================================================================================
#
# 📝 SAMPLE 5/10
# Expected: Standard
# Input: Age: 17.0, Occupation: Manager, Annual Income: 44286.36, Outstanding Debt: 2069.01, Credit Utilization Ratio: 37.48510261728924, Payment Behaviour: High_spent_Large_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# The individual is a 17-year-old manager with an annual income of $44,286.36 and has outstanding debt amounting to $2069. The credit utilization ratio at 37.48% suggests that the person's current debts are within reasonable limits relative to their total available credit. However, given the young age (17), it is important to consider if this level of spending behavior can be sustained over time without causing financial strain or debt accumulation.
#
# The payment behaviour described as "High_spent_Large_value_payments" indicates that while there might have been some large-value transactions in recent months, they do not necessarily indicate a problematic pattern. However, the high credit utilization ratio could still pose risks if this spending continues unchecked and becomes unsustainable with future income growth or changes in financial circumstances.
#
# Overall, considering these factors together suggests it is "Standard" to evaluate further without immediate red flags.
# </reasoning>
# answer
# Standard🤖 Model Prediction:
# <reasoning>
# The individual is a 17-year-old manager with an annual income of $44,286.36 and has outstanding debt amounting to $2069. The credit utilization ratio at 37.48% suggests that the person's current debts are within reasonable limits relative to their total available credit. However, given the young age (17), it is important to consider if this level of spending behavior can be sustained over time without causing financial strain or debt accumulation.
#
# The payment behaviour described as "High_spent_Large_value_payments" indicates that while there might have been some large-value transactions in recent months, they do not necessarily indicate a problematic pattern. However, the high credit utilization ratio could still pose risks if this spending continues unchecked and becomes unsustainable with future income growth or changes in financial circumstances.
#
# Overall, considering these factors together suggests it is "Standard" to evaluate further without immediate red flags.
# </reasoning>
# answer
# Standard
# ====================================================================================================
#
# 📝 SAMPLE 6/10
# Expected: Standard
# Input: Age: 31.0, Occupation: Teacher, Annual Income: 7889.11, Outstanding Debt: 973.01, Credit Utilization Ratio: 32.55273639375636, Payment Behaviour: Low_spent_Small_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# Based on the given information, a 31-year-old teacher with an annual income of $7889.11 has outstanding debt amounting to $973.01 and a credit utilization ratio at 32.55%. The payment behavior described as "Low_spent_Small_value_payments" suggests that the individual makes small payments frequently, which might indicate some financial discipline but also could imply lower overall spending or frequent late payments due to insufficient funds.
#
# Given these factors:
# - Income is below average for a teacher's salary.
# - Debt level seems manageable given their income and credit utilization ratio (which at 32.5% suggests they are within the moderate range).
# - The payment behavior does not provide clear insight into overall financial health since it could be due to various reasons including low spending or infrequent large transactions.
#
# Considering these points, this profile leans towards "Standard" as there isn't enough information either way regarding their ability to manage debt and finances effectively.
# </reasoning>
# <answer> Standard </answer>🤖 Model Prediction:
# <reasoning>
# Based on the given information, a 31-year-old teacher with an annual income of $7889.11 has outstanding debt amounting to $973.01 and a credit utilization ratio at 32.55%. The payment behavior described as "Low_spent_Small_value_payments" suggests that the individual makes small payments frequently, which might indicate some financial discipline but also could imply lower overall spending or frequent late payments due to insufficient funds.
#
# Given these factors:
# - Income is below average for a teacher's salary.
# - Debt level seems manageable given their income and credit utilization ratio (which at 32.5% suggests they are within the moderate range).
# - The payment behavior does not provide clear insight into overall financial health since it could be due to various reasons including low spending or infrequent large transactions.
#
# Considering these points, this profile leans towards "Standard" as there isn't enough information either way regarding their ability to manage debt and finances effectively.
# </reasoning>
# <answer> Standard </answer>
# ====================================================================================================
#
# 📝 SAMPLE 7/10
# Expected: Standard
# Input: Age: 39.0, Occupation: Scientist, Annual Income: 30450.84, Outstanding Debt: 203.69, Credit Utilization Ratio: 36.74535808122435, Payment Behaviour: Low_spent_Large_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# Based on the given information, this individual appears to have a reasonable financial profile. They are 39 years old and work as a scientist which generally indicates steady employment with potentially stable income sources. Their annual income of $30450.84 is adequate for their lifestyle considering they also carry some outstanding debt at $203.69, suggesting responsible spending habits or the use of credit cards to finance necessary expenses.
#
# The Credit Utilization Ratio (CUR) of 36.74% suggests that this individual uses a moderate portion of available credit which can be considered standard behavior for managing finances effectively without overextending themselves financially.
#
# Their payment behaviour described as "Low_spent_Large_value_payments" implies they are making payments on time and possibly have some disciplined spending habits, although the exact context is not specified.
#
# Given these factors, this individual's financial profile seems to fall within a standard range.
# </reasoning>
# <answer>Standard</answer>🤖 Model Prediction:
# <reasoning>
# Based on the given information, this individual appears to have a reasonable financial profile. They are 39 years old and work as a scientist which generally indicates steady employment with potentially stable income sources. Their annual income of $30450.84 is adequate for their lifestyle considering they also carry some outstanding debt at $203.69, suggesting responsible spending habits or the use of credit cards to finance necessary expenses.
#
# The Credit Utilization Ratio (CUR) of 36.74% suggests that this individual uses a moderate portion of available credit which can be considered standard behavior for managing finances effectively without overextending themselves financially.
#
# Their payment behaviour described as "Low_spent_Large_value_payments" implies they are making payments on time and possibly have some disciplined spending habits, although the exact context is not specified.
#
# Given these factors, this individual's financial profile seems to fall within a standard range.
# </reasoning>
# <answer>Standard</answer>
# ====================================================================================================
#
# 📝 SAMPLE 8/10
# Expected: Bad
# Input: Age: 22.0, Occupation: Media_Manager, Annual Income: 59102.91, Outstanding Debt: 3847.48, Credit Utilization Ratio: 27.347995916297727, Payment Behaviour: High_spent_Small_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# Based on the provided information, a 22-year-old media manager with an annual income of $59,102.91 has outstanding debt amounting to $3847.48 and a credit utilization ratio of 27.35%. The payment behavior described as "High_spent_Small_value_payments" suggests that while the individual is spending money frequently (which could be seen positively), they are also making smaller payments, which might indicate financial discipline but with potentially lower impact on reducing debt.
#
# The age factor alone does not provide a clear indication of risk; however, it's generally considered young and thus less experienced in managing finances. The credit utilization ratio at 27% is relatively low compared to the general threshold (typically below 30%) which suggests responsible use of available credit but also indicates that they might have limited debt exposure.
#
# Given these factors, a "Standard" risk assessment seems appropriate.
# </reasoning>
# answer
# Standard🤖 Model Prediction:
# <reasoning>
# Based on the provided information, a 22-year-old media manager with an annual income of $59,102.91 has outstanding debt amounting to $3847.48 and a credit utilization ratio of 27.35%. The payment behavior described as "High_spent_Small_value_payments" suggests that while the individual is spending money frequently (which could be seen positively), they are also making smaller payments, which might indicate financial discipline but with potentially lower impact on reducing debt.
#
# The age factor alone does not provide a clear indication of risk; however, it's generally considered young and thus less experienced in managing finances. The credit utilization ratio at 27% is relatively low compared to the general threshold (typically below 30%) which suggests responsible use of available credit but also indicates that they might have limited debt exposure.
#
# Given these factors, a "Standard" risk assessment seems appropriate.
# </reasoning>
# answer
# Standard
# ====================================================================================================
#
# 📝 SAMPLE 9/10
# Expected: Bad
# Input: Age: 38.0, Occupation: Mechanic, Annual Income: 44983.95, Outstanding Debt: 2998.57, Credit Utilization Ratio: 24.75993117068417, Payment Behaviour: High_spent_Medium_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# Based on the information provided, a 38-year-old Mechanic with an annual income of $44,983.95 has relatively low financial resources compared to their age and occupation level. Their credit utilization ratio is at Standard levels (20-25% generally considered good), which suggests they are managing debt well relative to available credit. However, the payment behavior described as "High_spent_Medium_value_payments" could indicate a tendency towards impulsive spending rather than disciplined saving or investing habits. This might not be inherently bad but requires monitoring for potential issues such as overspending on non-essential items which can lead to financial strain over time.
#
# Given these factors:
# 1. Low income relative to age and occupation.
# 2. Credit utilization in the standard range (not high).
# 3. Potential risk of impulsive spending patterns leading to future debt or financial stress if not managed properly.
#
# Considering all aspects, this profile leans towards "Bad" as there are underlying concerns about long-term stability that could be mitigated with better budgeting and savings habits.
# </reasoning>
# answer
# Bad🤖 Model Prediction:
# <reasoning>
# Based on the information provided, a 38-year-old Mechanic with an annual income of $44,983.95 has relatively low financial resources compared to their age and occupation level. Their credit utilization ratio is at Standard levels (20-25% generally considered good), which suggests they are managing debt well relative to available credit. However, the payment behavior described as "High_spent_Medium_value_payments" could indicate a tendency towards impulsive spending rather than disciplined saving or investing habits. This might not be inherently bad but requires monitoring for potential issues such as overspending on non-essential items which can lead to financial strain over time.
#
# Given these factors:
# 1. Low income relative to age and occupation.
# 2. Credit utilization in the standard range (not high).
# 3. Potential risk of impulsive spending patterns leading to future debt or financial stress if not managed properly.
#
# Considering all aspects, this profile leans towards "Bad" as there are underlying concerns about long-term stability that could be mitigated with better budgeting and savings habits.
# </reasoning>
# answer
# Bad
# ====================================================================================================
#
# 📝 SAMPLE 10/10
# Expected: Bad
# Input: Age: 37.0, Occupation: Mechanic, Annual Income: 18666.83, Outstanding Debt: 4072.19, Credit Utilization Ratio: 26.692371876812206, Payment Behaviour: Low_spent_Medium_value_payments
# --------------------------------------------------------------------------------
# <reasoning>
# Based on the given information, this individual appears to have a low credit utilization ratio (26.69%), which is generally considered good for managing debt and maintaining healthy financial behavior. However, they are an unskilled worker with a relatively modest annual income of $18,667. Their outstanding debt ($4072) represents about 23% of their monthly take-home pay (assuming the credit utilization ratio reflects spending habits), which is manageable but not negligible for someone in this financial situation.
#
# The payment behavior described as "Low_spent_Medium_value_payments" suggests that while they are responsible with how much money they spend, there isn't a strong indication about whether or not their payments are consistently on time. This could be seen as mixed; it's better than high-spending and late-payment habits but lacks the detail of knowing if all debts were paid in full each month.
#
# Given these factors, this individual is at Standard risk level.
# </reasoning>
# <answer>Standard</answer>🤖 Model Prediction:
# <reasoning>
# Based on the given information, this individual appears to have a low credit utilization ratio (26.69%), which is generally considered good for managing debt and maintaining healthy financial behavior. However, they are an unskilled worker with a relatively modest annual income of $18,667. Their outstanding debt ($4072) represents about 23% of their monthly take-home pay (assuming the credit utilization ratio reflects spending habits), which is manageable but not negligible for someone in this financial situation.
#
# The payment behavior described as "Low_spent_Medium_value_payments" suggests that while they are responsible with how much money they spend, there isn't a strong indication about whether or not their payments are consistently on time. This could be seen as mixed; it's better than high-spending and late-payment habits but lacks the detail of knowing if all debts were paid in full each month.
#
# Given these factors, this individual is at Standard risk level.
# </reasoning>
# <answer>Standard</answer>
# ====================================================================================================
#
# ✅ Completed predictions for all 10 samples!

# %%
# Display summary of all predictions
if llm is not None and 'results' in locals():
    print("\n📊 PREDICTION SUMMARY")
    print("=" * 100)
    
    correct_predictions = 0
    total_predictions = len(results)
    
    for result in results:
        # Extract the answer from prediction (look for <answer> tags)
        prediction_text = result['prediction']
        if '<answer>' in prediction_text and '</answer>' in prediction_text:
            start = prediction_text.find('<answer>') + 8
            end = prediction_text.find('</answer>')
            predicted_answer = prediction_text[start:end].strip()
        else:
            predicted_answer = "Could not parse"
        
        is_correct = predicted_answer == result['expected']
        if is_correct:
            correct_predictions += 1
        
        status = "✅ CORRECT" if is_correct else "❌ INCORRECT"
        
        print(f"\nSample {result['sample']}: {status}")
        print(f"Expected: {result['expected']}")
        print(f"Predicted: {predicted_answer}")
        print(f"Input: {result['input'][:60]}...")
    
    accuracy = (correct_predictions / total_predictions) * 100
    print(f"\n🎯 OVERALL ACCURACY: {correct_predictions}/{total_predictions} = {accuracy:.1f}%")
    
else:
    print("❌ No results to display")

# %%
# Test with LoRA model
from load_lora_model import load_lora_model, ask_financial_risk_lora

print("🔄 Loading LoRA model...")
try:
    lora_llm = load_lora_model()
    print("✅ LoRA model loaded successfully!")
    
    print("\n🚀 Running LoRA predictions on all 10 samples...")
    print("=" * 100)
    
    lora_results = []
    correct_lora = 0
    
    for i, example in enumerate(evaluation_data, 1):
        print(f"\n📝 SAMPLE {i}: Expected = {example['answer']}")
        try:
            prediction = ask_financial_risk_lora(example['question'], lora_llm)
            
            # Extract answer from prediction
            if '<answer>' in prediction and '</answer>' in prediction:
                start = prediction.find('<answer>') + 8
                end = prediction.find('</answer>')
                predicted = prediction[start:end].strip()
            else:
                predicted = "Could not parse"
            
            is_correct = predicted == example['answer']
            if is_correct:
                correct_lora += 1
            
            status = "✅" if is_correct else "❌"
            print(f"{status} Predicted: {predicted}")
            print(f"Input: {example['question'][:60]}...")
            
        except Exception as e:
            print(f"❌ Error: {e}")
    
    lora_accuracy = (correct_lora / len(evaluation_data)) * 100
    print(f"\n🎯 LoRA ACCURACY: {correct_lora}/{len(evaluation_data)} = {lora_accuracy:.1f}%")
    
except Exception as e:
    print(f"❌ Error loading LoRA model: {e}")
# Out:
# 🔄 Loading LoRA model...
# llama_context: n_ctx_per_seq (2048) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ✅ LoRA model loaded successfully!
#
# 🚀 Running LoRA predictions on all 10 samples...
# ====================================================================================================
#
# 📝 SAMPLE 1: Expected = Good
# <reasoning>
# Based on the information provided, a 19-year-old musician with an annual income of $18,246.25 has a credit utilization ratio of 40.44%. This is generally considered high, which could be a red flag for potential lenders. The payment behavior described as "Low_spent_Small_value_payments" suggests that the individual might have a history of making smaller rather than larger payments, which could indicate an inconsistent payment history. However, the annual income of $18,246.25 is not sufficient to cover an outstanding debt of $845.61, which might not be a good sign. Nonetheless, the combination of high credit utilization and low income does not constitute a "Good" risk profile, so we will categorize this as a "Standard" risk.
# </reasoning>
# <answer>
# Standard
# </answer>❌ Predicted: Standard
# Input: Age: 19.0, Occupation: Musician, Annual Income: 18246.25_, O...
#
# 📝 SAMPLE 2: Expected = Good
# <reasoning>
# Based on the information provided, a 20-year-old doctor with an annual income of $38,197.25 has an outstanding debt of $898.75 and a credit utilization ratio of 30.70%, which is relatively moderate. The payment behavior described as "High_spent_Medium_value_payments" suggests a balance between impulsive spending and controlled expenditures. This combination is generally considered good, as the individual is demonstrating a balanced approach to spending and debt management.
#
# The age and profession could also be seen as factors, as young doctors are often in positions where they have higher income potential relative to expenses, and their occupation is typically seen as financially stable.
#
# Overall, the individual's financial behavior shows promise and adherence to prudent financial management practices.
# </reasoning>
# <answer>
# Good
# </answer>✅ Predicted: Good
# Input: Age: 20.0, Occupation: Doctor, Annual Income: 38197.25, Outs...
#
# 📝 SAMPLE 3: Expected = Good
# <reasoning>
# The provided data points are somewhat limited for a comprehensive financial risk analysis, but we can still make some inferences. The age of 37 is generally considered a mature age where financial responsibilities have typically been established. The occupation of a doctor suggests a stable income, which is generally indicative of a good financial status. The outstanding debt of $107.8 is relatively small compared to the annual income of $14,619.875, which suggests a manageable debt load. However, the credit utilization ratio of 33.09% is somewhat high, as it indicates that the consumer is using 33% of their available credit, which can be a red flag for potential credit risk. Lastly, the payment behavior described as "Low_spent_Small_value_payments" suggests a pattern of minimal spending, which is generally not a cause for concern regarding financial risk, but it doesn't necessarily indicate a high level of financial responsibility either.
# </reasoning>
# Bad
# <answer>
# Bad
# </answer>❌ Predicted: Bad
# Input: Age: 37.0, Occupation: Doctor, Annual Income: 14619.875_, Ou...
#
# 📝 SAMPLE 4: Expected = Good
# <reasoning>
# Based on the information provided, a 23-year-old musician with an annual income of $19,028.33, a small amount of outstanding debt ($457.92), a credit utilization ratio of 36.66%, and a payment behavior indicating low-spending and small value payments, falls into the "Standard" category for risk assessment in financial analysis. Younger individuals with lower incomes and more moderate debt levels generally have lower risk profiles, as they are less likely to experience significant financial hardships. However, the high credit utilization ratio of 36.66% is somewhat concerning and suggests that this individual might be nearing their credit limit, which could potentially impact their credit score. Despite this, given their lower overall risk factors, the classification remains "Standard."
# </reasoning>
# <answer>
# Standard
# </answer>❌ Predicted: Standard
# Input: Age: 23.0, Occupation: Musician, Annual Income: 19028.33, Ou...
#
# 📝 SAMPLE 5: Expected = Standard
# <reasoning>
# The individual's age is below the typical retirement age and they are working in a managerial position, which suggests they have a stable income source. However, they have a significant outstanding debt, which is 4.64% of their annual income (2069.01 / 44286.36 * 100). The credit utilization ratio of 37.49% is above the generally recommended limit of 30%, which could be a concern for their credit score. The payment behavior of 'High_spent_Large_value_payments' indicates that they are making large payments, which can be seen as a positive sign, but the outstanding debt might still be a cause for concern.
# </reasoning>
# Bad❌ Predicted: Could not parse
# Input: Age: 17.0, Occupation: Manager, Annual Income: 44286.36, Out...
#
# 📝 SAMPLE 6: Expected = Standard
# <reasoning>
# Based on the given information, the credit utilization ratio is 32.55%. Typically, a credit utilization ratio below 30% is considered good. The age of 31 is relatively young and within the prime working age, which is generally considered a positive factor. The occupation as a teacher is stable and provides a regular income, which is typically seen as a positive attribute for creditworthiness. The annual income of $7,889.11 is low, which could be a concern. However, the low credit utilization ratio and the low payment behavior (indicating low spending and small-value payments) suggest that the individual manages their credit responsibly. With a low income and a moderate credit utilization, a "Standard" rating seems appropriate.
# </reasoning>
# <answer>
# Standard
# </answer>✅ Predicted: Standard
# Input: Age: 31.0, Occupation: Teacher, Annual Income: 7889.11, Outs...
#
# 📝 SAMPLE 7: Expected = Standard
# <reasoning>
# Given the information, the individual's age of 39.0 is within a prime working age range. The occupation as a Scientist implies a potentially stable income source. The annual income of $30,450.84 is considered average for the job role. The outstanding debt of $203.69 is small and not a significant financial risk. The credit utilization ratio of 36.74% is moderate and generally acceptable, but could be improved to better demonstrate financial responsibility. The payment behavior described as "Low_spent_Large_value_payments" suggests that the individual might have a disciplined spending pattern, especially if "Low_spent" indicates less than average spending behavior. Overall, these factors suggest that the financial situation is generally good.
# </reasoning>
# answer:
# Good❌ Predicted: Could not parse
# Input: Age: 39.0, Occupation: Scientist, Annual Income: 30450.84, O...
#
# 📝 SAMPLE 8: Expected = Bad
# <reasoning>
# Based on the given financial metrics, the individual's credit utilization ratio of 27.35% is below the generally accepted threshold of 30%, which is considered a good credit health indicator. The high-spent-small-value-payments behavior might suggest some variability in payment habits, but it doesn't necessarily indicate a bad credit behavior unless it becomes consistent with late payments or missed payments. The outstanding debt of $3847.48 is relatively low compared to the annual income of $59,102.91, suggesting the individual can manage their debt without much strain. Age and occupation do not directly impact the assessment of creditworthiness, but for a 22-year-old, being in a high-spent-small-value payments behavior could be a concern if it leads to inconsistent payments over time. Therefore, given the positive aspects in the financial metrics, the behavior could be considered standard.
# </reasoning>
# answer
# Standard❌ Predicted: Could not parse
# Input: Age: 22.0, Occupation: Media_Manager, Annual Income: 59102.9...
#
# 📝 SAMPLE 9: Expected = Bad
# <reasoning>
# Given the information provided, let's analyze the financial risk factors. Age is not particularly relevant to financial risk assessment. The occupation as a Mechanic suggests a stable but not high-income source. The Annual Income of $44,983.95 is modest, which may be a risk factor due to lower financial cushion. The Outstanding Debt of $2,998.57 is relatively small and manageable, but it's still a factor. The Credit Utilization Ratio of 24.7599% is relatively low, which is generally considered a positive indicator. The Payment Behaviour described as "High_spent_Medium_value_payments" might suggest a healthy spending pattern, but without more context (such as payment patterns for large and recurring expenses), it could be a mixed signal.
#
# Given these factors, the payment pattern and debt level could be viewed as a "Good" signal, while the modest income level and low credit utilization ratio also support a "Good" assessment.
#
# In financial risk assessment, a combination of factors (such as income level, debt burden, and credit utilization) is considered. Since the debt is manageable, income is stable, and the credit utilization is low, the overall financial health appears to be "Good❌ Predicted: Could not parse
# Input: Age: 38.0, Occupation: Mechanic, Annual Income: 44983.95, Ou...
#
# 📝 SAMPLE 10: Expected = Bad
# <reasoning>
# Based on the given information, the individual's credit utilization ratio of 26.69% is relatively healthy and within a prudent range, suggesting they are not maxing out their credit cards. However, the payment behavior described as "Low_spent_Medium_value_payments" suggests that the individual's spending is not particularly high or risky, but they are also not making large payments. This could imply that they are spending more than they need but not heavily, which might indicate a potential for future financial strain if their spending increases or if they encounter unexpected expenses. Their annual income of $18,666.83 and outstanding debt of $4,072.19 suggest a manageable financial situation, but with room for improvement in managing debt if necessary. Given the balance between prudent credit usage and moderate spending, the overall risk profile falls into the "Standard" category.
# </reasoning>
# <answer>
# Standard
# </answer>❌ Predicted: Standard
# Input: Age: 37.0, Occupation: Mechanic, Annual Income: 18666.83, Ou...
#
# 🎯 LoRA ACCURACY: 2/10 = 20.0%

# %%
# Test with Base Model (no fine-tuning)
from llama_cpp import Llama

print("🔄 Loading Base Model...")
try:
    base_llm = Llama(
        model_path=r"D:\Narwal\fine-tuning-lora-qlora\qwen2.5-3b-instruct-q8_0.gguf",
        n_ctx=2048,
        n_threads=8,
        n_batch=512,
        verbose=False
    )
    print("✅ Base model loaded successfully!")
    
    print("\n🚀 Running Base Model predictions on all 10 samples...")
    print("=" * 100)
    
    correct_base = 0
    
    for i, example in enumerate(evaluation_data, 1):
        print(f"\n📝 SAMPLE {i}: Expected = {example['answer']}")
        
        prompt = f"""You are a financial risk analysis assistant.
Respond in the following format:
<reasoning>
(your reasoning here)
</reasoning>
<answer>
Choose exactly one of: "Good", "Bad", or "Standard"
</answer>

{example['question']}
"""
        
        try:
            prediction = ""
            for chunk in base_llm.create_completion(
                prompt,
                max_tokens=500,
                stream=True,
                temperature=0.3,
                top_p=0.9,
                repeat_penalty=1.2,
                top_k=40
            ):
                prediction += chunk["choices"][0]["text"]
            
            # Extract answer from prediction
            if '<answer>' in prediction and '</answer>' in prediction:
                start = prediction.find('<answer>') + 8
                end = prediction.find('</answer>')
                predicted = prediction[start:end].strip()
            else:
                predicted = "Could not parse"
            
            is_correct = predicted == example['answer']
            if is_correct:
                correct_base += 1
            
            status = "✅" if is_correct else "❌"
            print(f"{status} Predicted: {predicted}")
            print(f"Input: {example['question'][:60]}...")
            
        except Exception as e:
            print(f"❌ Error: {e}")
    
    base_accuracy = (correct_base / len(evaluation_data)) * 100
    print(f"\n🎯 BASE MODEL ACCURACY: {correct_base}/{len(evaluation_data)} = {base_accuracy:.1f}%")
    
except Exception as e:
    print(f"❌ Error loading Base model: {e}")
# Out:
# 🔄 Loading Base Model...
# llama_context: n_ctx_per_seq (2048) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ✅ Base model loaded successfully!
#
# 🚀 Running Base Model predictions on all 10 samples...
# ====================================================================================================
#
# 📝 SAMPLE 1: Expected = Good
# ❌ Predicted: Could not parse
# Input: Age: 19.0, Occupation: Musician, Annual Income: 18246.25_, O...
#
# 📝 SAMPLE 2: Expected = Good
# ❌ Predicted: Could not parse
# Input: Age: 20.0, Occupation: Doctor, Annual Income: 38197.25, Outs...
#
# 📝 SAMPLE 3: Expected = Good
# ❌ Predicted: Could not parse
# Input: Age: 37.0, Occupation: Doctor, Annual Income: 14619.875_, Ou...
#
# 📝 SAMPLE 4: Expected = Good
# ✅ Predicted: Good
# Input: Age: 23.0, Occupation: Musician, Annual Income: 19028.33, Ou...
#
# 📝 SAMPLE 5: Expected = Standard
# ❌ Predicted: Bad
# Input: Age: 17.0, Occupation: Manager, Annual Income: 44286.36, Out...
#
# 📝 SAMPLE 6: Expected = Standard
# ✅ Predicted: Standard
# Input: Age: 31.0, Occupation: Teacher, Annual Income: 7889.11, Outs...
#
# 📝 SAMPLE 7: Expected = Standard
# ❌ Predicted: Could not parse
# Input: Age: 39.0, Occupation: Scientist, Annual Income: 30450.84, O...
#
# 📝 SAMPLE 8: Expected = Bad
# ❌ Predicted: Could not parse
# Input: Age: 22.0, Occupation: Media_Manager, Annual Income: 59102.9...
#
# 📝 SAMPLE 9: Expected = Bad
# ❌ Predicted: Standard
# Input: Age: 38.0, Occupation: Mechanic, Annual Income: 44983.95, Ou...
#
# 📝 SAMPLE 10: Expected = Bad
# ❌ Predicted: Standard
# Input: Age: 37.0, Occupation: Mechanic, Annual Income: 18666.83, Ou...
#
# 🎯 BASE MODEL ACCURACY: 2/10 = 20.0%
